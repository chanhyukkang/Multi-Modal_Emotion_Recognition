# %%
from pyAudioAnalysis import audioBasicIO
# from pyAudioAnalysis import audioFeatureExtraction
from pyAudioAnalysis import ShortTermFeatures
import matplotlib.pyplot as plt
import pandas as pd
import os
from os import walk 
import librosa
import numpy as np

# %%
df = pd.read_csv('C:/Users/KangChanhyuk/Desktop/자주연1/audio_test_speech - 복사본.csv', engine = 'python') 

season = []
episode = []
starttime = []
endtime = []
filename = []

print(len(df))


for i in range( 0, len(df) ) : 
    season.append( "0"+str(df["Season"][i]) )
    
    filename.append ( str(df["Filename"][i]) )  
    print(filename[i])
    filename[i] = filename[i][:len(filename[i])-4]
    print(filename[i])
# Out:
# 11376
# FriendsS01E01_79036.wav
# FriendsS01E01_79036
# FriendsS01E01_85627.wav
# FriendsS01E01_85627
# FriendsS01E01_87377.wav
# FriendsS01E01_87377
# FriendsS01E01_94928.wav
# FriendsS01E01_94928
# FriendsS01E01_95600.wav
# FriendsS01E01_95600
# FriendsS01E01_97055.wav
# FriendsS01E01_97055
# FriendsS01E01_97973.wav
# FriendsS01E01_97973
# FriendsS01E01_98723.wav
# FriendsS01E01_98723
# FriendsS01E01_202660.wav
# FriendsS01E01_202660
# FriendsS01E01_209959.wav
# FriendsS01E01_209959
# FriendsS01E01_214214.wav
# FriendsS01E01_214214
# FriendsS01E01_283666.wav
# FriendsS01E01_283666
# FriendsS01E01_325450.wav
# FriendsS01E01_325450
# FriendsS01E01_611861.wav
# FriendsS01E01_611861
# FriendsS01E01_636427.wav
# FriendsS01E01_636427
# FriendsS01E01_640890.wav
# FriendsS01E01_640890
# FriendsS01E01_644560.wav
# FriendsS01E01_644560
# FriendsS01E01_648773.wav
# FriendsS01E01_648773
# FriendsS01E01_650775.wav
# FriendsS01E01_650775
# FriendsS01E01_653276.wav
# FriendsS01E01_653276
# ...

# %%
#### step3. Feature Extraction

# 3-1. 34 Features of each frame
# 3-2. Mean of 34 Features

# y, sr = librosa.load(os.getcwd() + "\Desktop\자주연1\Friends\Friends_Audio_Separate\S1\FriendsS01E01_79036.wav")  # Y gives 
# mfcc_data = librosa.feature.mfcc(y=y, sr=sr)

#################################################
print(len(df))
for i in range(6523, len(df)) : 

    # [Fs, x] = audioBasicIO.read_audio_file('C:\\Users\KangChanhyuk\Desktop\자주연1\Friends\Friends_Audio_Separate\S'+str(df['Season'][i])+'\\'+df["Filename"][i]);
    [Fs, x] = audioBasicIO.read_audio_file('C:\\Users\KangChanhyuk\Desktop\자주연1\Friends\Friends_Audio_Speech\S'+str(df['Season'][i])+'\\'+filename[i]+'\\vocals.wav');

    F, f_names = ShortTermFeatures.feature_extraction(audioBasicIO.stereo_to_mono(x), Fs, 0.050*Fs, 0.025*Fs);

    data = pd.DataFrame(F.T)

    for n in range(0,len(f_names)) :
        df.loc[i, [f_names[n]]] = data[n].mean()

    df.to_csv("C:/Users/KangChanhyuk/Desktop/자주연1/audio_test_speech.csv", mode='w')
    print(i)
#################################################   
print("done")

# print('Features Shape', F.shape)
# print('Feature Names', f_names)

# plt.subplot(2,2,1); plt.plot(F[0,:]); plt.xlabel('Frame no'); plt.ylabel(f_names[0]); 
# plt.subplot(2,2,2); plt.plot(F[1,:]); plt.xlabel('Frame no'); plt.ylabel(f_names[1]); 
# plt.subplot(2,2,3); plt.plot(F[2,:]); plt.xlabel('Frame no'); plt.ylabel(f_names[2]); 
# plt.subplot(2,2,4); plt.plot(F[3,:]); plt.xlabel('Frame no'); plt.ylabel(f_names[3]); 

# plt.show()
# Out:
# 11376
# 6523
# 6524
# 6525
# 6526
# 6527
# 6528
# 6529
# 6530
# 6531
# 6532
# 6533
# 6534
# 6535
# 6536
# 6537
# 6538
# 6539
# 6540
# 6541
# 6542
# 6543
# 6544
# 6545
# 6546
# 6547
# 6548
# 6549
# 6550
# 6551
# 6552
# 6553
# 6554
# 6555
# 6556
# 6557
# 6558
# 6559
# 6560
# 6561
# 6562
# 6563
# 6564
# 6565
# 6566
# 6567
# 6568
# 6569
# 6570
# 6571
# 6572
# 6573
# 6574
# 6575
# 6576
# 6577
# 6578
# 6579
# 6580
# 6581
# 6582
# 6583
# 6584
# 6585
# 6586
# 6587
# 6588
# 6589
# 6590
# 6591
# 6592
# 6593
# 6594
# 6595
# 6596
# 6597
# 6598
# 6599
# 6600
# 6601
# 6602
# 6603
# 6604
# 6605
# 6606
# 6607
# 6608
# 6609
# 6610
# 6611
# 6612
# 6613
# 6614
# 6615
# 6616
# 6617
# 6618
# 6619
# 6620
# 6621
# 6622
# 6623
# 6624
# 6625
# 6626
# 6627
# 6628
# 6629
# 6630
# 6631
# 6632
# 6633
# 6634
# 6635
# 6636
# 6637
# 6638
# 6639
# 6640
# 6641
# 6642
# 6643
# 6644
# 6645
# 6646
# 6647
# 6648
# 6649
# 6650
# 6651
# 6652
# 6653
# 6654
# 6655
# 6656
# 6657
# 6658
# 6659
# 6660
# 6661
# 6662
# 6663
# ...

# %%
df = pd.DataFrame(mfcc_data)
df
# Out:
#            0           1           2           3           4           5    \
# 0  -272.222260 -271.724457 -266.422455 -248.073746 -255.509964 -261.298553
# 1   133.139709  133.317566  132.989838  134.801483  138.925568  138.745377
# 2    27.030235   12.370194   -9.745601  -16.598520  -13.511680   -7.805500
# 3    42.170528   42.655151   51.053162   65.138504   63.063812   49.276894
# 4    -5.700315   -8.355647  -14.858049  -22.364979  -25.581917  -20.943048
# 5    19.597162   20.372723   24.206429   26.501505   21.020046   20.172247
# 6     5.488637    4.303986    2.857778    7.452007    6.756106    1.780820
# 7     9.597099    8.153836   -1.493719  -10.735277  -13.407065  -13.379721
# 8    -7.700988   -6.105617   -9.079580   -6.565533   -6.262824  -12.902379
# 9   -16.832581   -9.828445   -9.403008   -6.188559   -2.923717    1.517009
# 10  -26.539951  -21.537182  -12.615318   -4.450557   -6.143120   -5.923635
# ...
